# %%
#Ridge and Lasso Regression

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
ridge=Ridge()
params = {'alpha' : [1e-14,1e-9,1e-5,1e-2,2,6,11]}
ridge_regression = GridSearchCV(ridge,params,scoring="neg_mean_squared_error",cv=5)

# %%
df=pd.read_csv('ridge_lasso_train.csv')

# %%
df
# Out:
#      Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0     0.595029   0.414900  -0.412998  -0.179907  -0.031439   0.402693
# 1    -0.397195  -0.630886   0.347562  -0.045967   0.355669   0.729911
# 2    -0.963759  -0.775467   0.343788   0.676634   0.032797  -0.116561
# 3     0.105894  -0.051013   1.976441   0.971488   1.617213   0.610091
# 4    -1.050141  -0.648554   1.370536   1.325460   0.283751   0.368811
# ..         ...        ...        ...        ...        ...        ...
# 155   0.317453   0.195114  -0.093387  -0.254378  -1.514470  -0.632493
# 156   0.164761   0.115995   0.173342   0.134987  -0.223202  -0.053738
# 157  -0.718832  -0.597762  -0.194697  -0.581505   0.091752  -0.180681
# 158   0.586166   0.400357   0.257199  -0.052910   0.007880   0.337375
# 159   1.200262   1.230424  -0.411427  -0.580235  -1.869742  -1.755280
#
#      Feature_6  Feature_7  Feature_8  Feature_9    Target
# 0     0.573128  -1.785866  -0.359630   0.301107  1.699480
# ...

# %%
X=df.iloc[:,:-1]
X
# Out:
#      Feature_0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  \
# 0     0.595029   0.414900  -0.412998  -0.179907  -0.031439   0.402693
# 1    -0.397195  -0.630886   0.347562  -0.045967   0.355669   0.729911
# 2    -0.963759  -0.775467   0.343788   0.676634   0.032797  -0.116561
# 3     0.105894  -0.051013   1.976441   0.971488   1.617213   0.610091
# 4    -1.050141  -0.648554   1.370536   1.325460   0.283751   0.368811
# ..         ...        ...        ...        ...        ...        ...
# 155   0.317453   0.195114  -0.093387  -0.254378  -1.514470  -0.632493
# 156   0.164761   0.115995   0.173342   0.134987  -0.223202  -0.053738
# 157  -0.718832  -0.597762  -0.194697  -0.581505   0.091752  -0.180681
# 158   0.586166   0.400357   0.257199  -0.052910   0.007880   0.337375
# 159   1.200262   1.230424  -0.411427  -0.580235  -1.869742  -1.755280
#
#      Feature_6  Feature_7  Feature_8  Feature_9
# 0     0.573128  -1.785866  -0.359630   0.301107
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      1.699480
# 1     -1.622640
# 2     -2.659128
# 3     -1.768708
# 4     -3.612518
#          ...
# 155   -0.098808
# 156    0.546271
# 157    2.014654
# 158   -2.240922
# 159    1.772206
# Name: Target, Length: 160, dtype: float64

# %%
ridge_regression.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-14, 1e-09, 1e-05, 0.01, 2, 6, 11]},
#              scoring='neg_mean_squared_error')

# %%
ridge_regression.best_params_
# Out:
# {'alpha': 0.01}

# %%
ridge_regression.best_score_
# Out:
# -0.28303368950232244

# %%
from sklearn.linear_model import Lasso

# %%
lasso = Lasso()
lasso_regression = GridSearchCV(lasso,params,scoring="neg_mean_squared_error",cv=5)

# %%
lasso_regression.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1e-14, 1e-09, 1e-05, 0.01, 2, 6, 11]},
#              scoring='neg_mean_squared_error')

# %%
lasso_regression.best_params_
# Out:
# {'alpha': 0.01}

# %%
lasso_regression.best_score_
# Out:
# -0.2693838554318426
